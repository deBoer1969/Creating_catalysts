# %% [markdown]
# # Step 1 making the structure using ASE

# %% [markdown]
# Import all needed packages
# Genrate the crystal from crystal structure
# cut the crystal ensuring that the lattice is orientated in cell right
# multiply the cell to make more structure

# %%
import ase
import ase.spacegroup
from ase.spacegroup import crystal
from ase.visualize import view
from ase.io import read

import numpy as np
# %matplotlib notebook

# %%
# a, b, c refer to the lattice constants

a = 3.78
b = 3.78
c = 9.62 



basis_positions = [(1/2, 1/2, 1/2), (0, 1/2, 0.457152)]

primitive_structure = ase.spacegroup.crystal(['Ti', 'O'],
                                basis=basis_positions,
                                spacegroup=141,  
                                cellpar=[a, b, c, 90, 90, 90]
                                )

# %%
TiO2_repeate=primitive_structure.repeat((5, 5, 3))

TiO2_repeate.center(vacuum=10, axis=(0,1,2))

# %%
view(TiO2_repeate)
view(primitive_structure)
# Out:
# <Popen: returncode: None args: ['C:\\Users\\Joshu\\anaconda3\\envs\\myenv\\p...>

# %% [markdown]
# # Step 2 using the surface energies to make a wulffconstruct

# %%
from wulffpack import (SingleCrystal,
                       Decahedron,
                       Icosahedron)
from ase.build import bulk
from ase.io import write
import wulffpack as wp

# %%
prim = primitive_structure
surface_energies = {(1, 0, 0): 2.5,
                    (1, 1, 0): 3.5,
                    (1, 1, 1): 4.0}


particle = SingleCrystal(surface_energies,
                         primitive_structure=prim,
                         natoms=1500,
                         )

particle.view()
# Out:
# <img src="data:image/png;base64,..." width="600.6666666666666">

# %%
write('Al2O3_nanoparticle.cfg', particle.atoms)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 write('Al2O3_nanoparticle.cfg', particle.atoms)
#
# NameError: name 'write' is not defined
